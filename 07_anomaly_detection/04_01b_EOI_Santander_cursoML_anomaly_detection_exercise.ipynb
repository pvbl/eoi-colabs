# %%
# !pip install pyod
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.7/364.7 kB 16.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyod.models.iforest import IForest
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from sklearn.preprocessing import StandardScaler

# %%
# 1. Cargar el dataset (NYC Taxi)
#  dataset que registra el número de viajes cada 30 minutos.
url = "https://raw.githubusercontent.com/numenta/NAB/master/data/realKnownCause/nyc_taxi.csv"
df = pd.read_csv(url)
df['timestamp'] = pd.to_datetime(df['timestamp'])
X = df[['value']].values.astype(float) # La variable única
contamination = 0.005
n_neighbors=50 #(KKN y LOF)

# %% [markdown]
# Calcula:
# 1. Haz StandardScaler de X
# 2. Con boxplot whisker = 1.5 y 2.5 los outliers de X
# 3. Con Isolation forest contamination de X
# 4. KNN y LOF de X
# 5. Compara visualmente mediante un plot de la serie temporal los outliers de los diferentes modelos. Similar a la siguiente imagen
# ![image.png](data:image/png;base64,...)

# %%
# preprocesamiento con standar scaler para knn
#
# calcula anomalías de
