# %%
# !pip install tpot
# Out:
# Collecting tpot
#   Downloading TPOT-1.0.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (from tpot) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from tpot) (1.13.1)
# Collecting scikit-learn<1.6,>=1.4.2 (from tpot)
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting update-checker>=0.16 (from tpot)
#   Downloading update_checker-0.18.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from tpot) (4.67.1)
# Collecting stopit>=1.1.1 (from tpot)
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from tpot) (2.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from tpot) (1.4.2)
# Requirement already satisfied: xgboost>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from tpot) (2.1.4)
# Requirement already satisfied: matplotlib>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from tpot) (3.10.0)
# Collecting traitlets>=5.8.0 (from tpot)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: lightgbm>=3.3.3 in /usr/local/lib/python3.11/dist-packages (from tpot) (4.5.0)
# Collecting optuna>=3.0.5 (from tpot)
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from tpot) (3.4.2)
# Requirement already satisfied: dask>=2024.4.2 in /usr/local/lib/python3.11/dist-packages (from tpot) (2024.11.2)
# Requirement already satisfied: distributed>=2024.4.2 in /usr/local/lib/python3.11/dist-packages (from tpot) (2024.11.2)
# Requirement already satisfied: dask-expr>=1.0.12 in /usr/local/lib/python3.11/dist-packages (from tpot) (1.1.19)
# Collecting dask-jobqueue>=0.8.5 (from tpot)
#   Downloading dask_jobqueue-0.9.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting func-timeout>=4.3.5 (from tpot)
#   Downloading func_timeout-4.3.5.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 876.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting configspace>=1.1.1 (from tpot)
#   Downloading configspace-1.2.1.tar.gz (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 5.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dill>=0.3.9 (from tpot)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from tpot) (0.13.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from configspace>=1.1.1->tpot) (3.2.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from configspace>=1.1.1->tpot) (4.12.2)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.11/dist-packages (from configspace>=1.1.1->tpot) (10.6.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.2->tpot) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.2->tpot) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.2->tpot) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.2->tpot) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.2->tpot) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.2->tpot) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.2->tpot) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.2->tpot) (8.6.1)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr>=1.0.12->tpot) (18.1.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (3.1.5)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (2.3.0)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.2->tpot) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.2->tpot) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.2->tpot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.2->tpot) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.2->tpot) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.2->tpot) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.2->tpot) (2.8.2)
# Collecting alembic>=1.5.0 (from optuna>=3.0.5->tpot)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna>=3.0.5->tpot)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0.5->tpot) (2.0.38)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->tpot) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->tpot) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.6,>=1.4.2->tpot) (3.5.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from update-checker>=0.16->tpot) (2.32.3)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost>=1.7.0->tpot) (2.21.5)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0.5->tpot)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.13.0->dask>=2024.4.2->tpot) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.10.3->distributed>=2024.4.2->tpot) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->tpot) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0.5->tpot) (3.1.1)
# Downloading TPOT-1.0.0-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.0/214.0 kB 13.1 MB/s eta 0:00:00
# Downloading dask_jobqueue-0.9.0-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.5 MB/s eta 0:00:00
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 4.7 MB/s eta 0:00:00
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 22.7 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 42.6 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 3.8 MB/s eta 0:00:00
# Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 10.9 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.3 MB/s eta 0:00:00
# Building wheels for collected packages: configspace, func-timeout, stopit
#   Building wheel for configspace (pyproject.toml) ... done
#   Created wheel for configspace: filename=configspace-1.2.1-py3-none-any.whl size=115950 sha256=bb88be0c2dd3bfcf7e06baa1468c955de2033ff9e5b0bd0b8338625f40f3b72f
#   Stored in directory: /root/.cache/pip/wheels/11/0f/36/d5027c3eeb038827889830f7efbe6a1bad8956b3eb44ab2f44
#   Building wheel for func-timeout (setup.py) ... done
#   Created wheel for func-timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15076 sha256=662d06217cc0e16d314a7241dadf1ccda30e0d15197777c5de564bcd2fd1ae7f
#   Stored in directory: /root/.cache/pip/wheels/07/e6/86/f23164d12c3134966614102db8e7956ab359faf7ffd78703ce
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11939 sha256=f790a07f698d555722b6e37b67b83e98d405f0efc65dc34dc0c32bca684df70d
#   Stored in directory: /root/.cache/pip/wheels/da/77/2d/adbc56bc4db95ad80c6d4e71cd69e2d9d122174904342e3f7f
# Successfully built configspace func-timeout stopit
# Installing collected packages: stopit, func-timeout, traitlets, Mako, dill, colorlog, update-checker, scikit-learn, configspace, alembic, optuna, dask-jobqueue, tpot
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed Mako-1.3.9 alembic-1.14.1 colorlog-6.9.0 configspace-1.2.1 dask-jobqueue-0.9.0 dill-0.3.9 func-timeout-4.3.5 optuna-4.2.1 scikit-learn-1.5.2 stopit-1.1.2 tpot-1.0.0 traitlets-5.14.3 update-checker-0.18.0

# %% [markdown]
# # Selección de modelos

# %%
from sklearn import  tree
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import time

# %% [markdown]
# # Carga de datos
# Usamos de nuevo los datos para predecir la concesión de un préstamo

# %%
url_file = "https://raw.githubusercontent.com/zng489/Decision_trees_and_Random-Forest-madfhantr-/main/madfhantr.csv"
df_raw = pd.read_csv(url_file)
df_raw.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
def preprocessing_madfhantr(df):
  # eliminamos nans
  df = df.dropna()
  # creamos columna con nombres target
  df["targetNames"] = df["Loan_Status"]
  # variables categóricas que tenemos que convertir
  cat_vars = ["Gender","Married","Dependents","Education","Self_Employed","Property_Area","Loan_Status"]
  for cat_var in cat_vars:
    df[cat_var] = pd.Categorical(df[cat_var]).codes.astype("int")
  # renombramos la columna target
  df = df.rename(columns={"Loan_Status":"target"})
  df["target"] = df["target"].astype("int")
  df = df.set_index("Loan_ID")
  return df

# %%
df = preprocessing_madfhantr(df_raw)
# Out:
# <ipython-input-10-9467ba81db5f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["targetNames"] = df["Loan_Status"]
# <ipython-input-10-9467ba81db5f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cat_var] = pd.Categorical(df[cat_var]).codes.astype("int")
# <ipython-input-10-9467ba81db5f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cat_var] = pd.Categorical(df[cat_var]).codes.astype("int")
# <ipython-input-10-9467ba81db5f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cat_var] = pd.Categorical(df[cat_var]).codes.astype("int")
# <ipython-input-10-9467ba81db5f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cat_var] = pd.Categorical(df[cat_var]).codes.astype("int")
# <ipython-input-10-9467ba81db5f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cat_var] = pd.Categorical(df[cat_var]).codes.astype("int")
# <ipython-input-10-9467ba81db5f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cat_var] = pd.Categorical(df[cat_var]).codes.astype("int")
# <ipython-input-10-9467ba81db5f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cat_var] = pd.Categorical(df[cat_var]).codes.astype("int")

# %% [markdown]
# # Exploración de datos

# %%
df.head()
# Out:
#           Gender  Married  Dependents  Education  Self_Employed  \
# Loan_ID
# LP001003       1        1           1          0              0
# LP001005       1        1           0          0              1
# LP001006       1        1           0          1              0
# LP001008       1        0           0          0              0
# LP001011       1        1           2          0              1
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
# LP001011             5417             4196.0       267.0             360.0
#
#           Credit_History  Property_Area  target targetNames
# Loan_ID
# LP001003             1.0              0       0           N
# LP001005             1.0              2       1           Y
# LP001006             1.0              2       1           Y
# LP001008             1.0              2       1           Y
# LP001011             1.0              2       1           Y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 480 entries, LP001003 to LP002990
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             480 non-null    int64
#  1   Married            480 non-null    int64
#  2   Dependents         480 non-null    int64
#  3   Education          480 non-null    int64
#  4   Self_Employed      480 non-null    int64
#  5   ApplicantIncome    480 non-null    int64
#  6   CoapplicantIncome  480 non-null    float64
#  7   LoanAmount         480 non-null    float64
#  8   Loan_Amount_Term   480 non-null    float64
#  9   Credit_History     480 non-null    float64
#  10  Property_Area      480 non-null    int64
#  11  target             480 non-null    int64
#  12  targetNames        480 non-null    object
# dtypes: float64(4), int64(8), object(1)
# memory usage: 52.5+ KB

# %%
df.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  480.000000  480.000000  480.000000  480.000000     480.000000
# mean     0.820833    0.647917    0.777083    0.202083       0.137500
# std      0.383892    0.478118    1.020815    0.401973       0.344734
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.000000    0.000000    0.000000       0.000000
# 50%      1.000000    1.000000    0.000000    0.000000       0.000000
# 75%      1.000000    1.000000    2.000000    0.000000       0.000000
# max      1.000000    1.000000    3.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History  Property_Area      target
# count      480.000000     480.000000  480.000000
# mean         0.854167       1.022917    0.691667
# std          0.353307       0.776411    0.462287
# min          0.000000       0.000000    0.000000
# 25%          1.000000       0.000000    0.000000
# 50%          1.000000       1.000000    1.000000
# 75%          1.000000       2.000000    1.000000
# max          1.000000       2.000000    1.000000

# %% [markdown]
# # Modelización con GridSearch y Random Search con árboles de decisión
# Creamos un árbol de regresión haciendo un train/test split del 30%.

# %%
targetCol = "targetNames"
featuresCols = [col for col in df.columns if col not in ["target","targetNames"]]
X, y = df[featuresCols],df[targetCol]

# %%
mapper = dict(df[["targetNames","target",]].drop_duplicates().values)
mapper
# Out:
# {'N': 0, 'Y': 1}

# %%
featuresCols
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (360, 11)
# (120, 11)

# %% [markdown]
# ### Grid Search

# %%
grid = {
    'max_depth' : [3,5,7,9],
    'criterion' :['gini','entropy'],
    'random_state' : [18]
}
tree_cv = GridSearchCV(estimator=tree.DecisionTreeClassifier(), param_grid=grid, cv= 5)

# %%
# %%time
tree_cv.fit(X_train, y_train)
# Out:
# CPU times: user 258 ms, sys: 0 ns, total: 258 ms
# Wall time: 265 ms
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 9], 'random_state': [18]})

# %%
tree_cv.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=18)

# %%
#tree_cv.cv_results_

# %%
def plot_grid_search(cv_results, grid, name_param_1, name_param_2):
    grid_param_1 = grid[name_param_1]
    grid_param_2 = grid[name_param_2]
    # Get Test Scores Mean and std for each grid search
    scores_mean = cv_results['mean_test_score']
    scores_mean = np.array(scores_mean).reshape(len(grid_param_2),len(grid_param_1))

    scores_sd = cv_results['std_test_score']
    scores_sd = np.array(scores_sd).reshape(len(grid_param_2),len(grid_param_1))

    # Plot Grid search scores
    _, ax = plt.subplots(1,1)

    # Param1 is the X-axis, Param 2 is represented as a different curve (color line)
    for idx, val in enumerate(grid_param_2):
        ax.plot(grid_param_1, scores_mean[idx,:], '-o', label= name_param_2 + ': ' + str(val))

    ax.set_title("Grid Search Scores", fontsize=20, fontweight='bold')
    ax.set_xlabel(name_param_1, fontsize=16)
    ax.set_ylabel('CV Average Score', fontsize=16)
    ax.legend(loc="best", fontsize=15)
    ax.grid('on')

# Calling Method
plot_grid_search(tree_cv.cv_results_, grid, "max_depth", "criterion")

# %%
y_pred = tree_cv.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[15 28]
#  [ 7 70]]
#               precision    recall  f1-score   support
#
#            N       0.68      0.35      0.46        43
#            Y       0.71      0.91      0.80        77
#
#     accuracy                           0.71       120
#    macro avg       0.70      0.63      0.63       120
# weighted avg       0.70      0.71      0.68       120

# %% [markdown]
# ### Random Search

# %%
grid = {
    'max_depth' : [3,5,7],
    'criterion' :['gini','entropy'],
    'random_state' : [18]
}
tree_rs = RandomizedSearchCV(estimator=tree.DecisionTreeClassifier(), param_distributions =grid, cv= 5)

# %%
# %%time
tree_rs.fit(X_train, y_train)
# Out:
# CPU times: user 194 ms, sys: 763 µs, total: 195 ms
# Wall time: 194 ms
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, 5, 7],
#                                         'random_state': [18]})

# %%
tree_cv_best=tree_rs.best_estimator_
tree_cv_best
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=18)

# %%
y_pred = tree_rs.predict(X_test) # o tree_cv_best
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[15 28]
#  [ 7 70]]
#               precision    recall  f1-score   support
#
#            N       0.68      0.35      0.46        43
#            Y       0.71      0.91      0.80        77
#
#     accuracy                           0.71       120
#    macro avg       0.70      0.63      0.63       120
# weighted avg       0.70      0.71      0.68       120

# %%
pd.Series(tree_cv_best.feature_importances_,featuresCols).sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# # Modelización con Random Forest y XGBoost
# Ejercicio práctico
# **Random Forest**
# - Haz un modelo de Random Forest y usa Grid Search (con cv=5) para evaluar los mejores hiperparámetros. Evalúa los tiempos de cómputo con el comando %%time.
# El grid está definido en la siguiente celda.
# - Mira cual es el mejor estimador y evalúa los resultados con classification_report.
# - Muestra la feature Importance.
# - Haz el mismo proceso de evaluación de hiperparámetros con Grid Search, evaluando el tiempo de cómputo y mira si la solución obtenida es la misma a la del Grid Search.
#
# **XGBoost**
# - Realiza una cross validation con el XGboost
# - Haz un hiperparámeter tunning con el grid siguiente para XGboost

# %%
from sklearn import  ensemble

# %%
grid = {
    'n_estimators': [200,300,500],
    'max_features': ['sqrt', 'log2'],
    'max_depth' : [3,5,7,9],
    'criterion' :['gini'],
    'random_state' : [18]
}

# %%
# %%time
# haz el gridsearchCV con cv=5
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.39 µs

# %% [markdown]
# Evaluamos las métricas

# %%
# evalúa las métricas

# %%
# muestra el mejor estimador
rf_cv_best=None # completar

print(rf_cv_best)
# Out:
# None

# %%
# muestra la feature importance

# %%
# %%time
## haz el randomized search con cv=5
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 11.2 µs

# %% [markdown]
# **Cross Validation e hiperparámeter tuning usando XGboost**

# %%
import xgboost as xgb

# %%
targetCol = "target"
featuresCols = [col for col in df.columns if col not in ["target","targetNames"]]
X, y = df[featuresCols],df[targetCol]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
y_train
# Out:
# Loan_ID
# LP001432    1
# LP001384    1
# LP002537    1
# LP001349    1
# LP001186    0
#            ..
# LP002068    1
# LP001318    1
# LP002634    1
# LP001954    1
# LP001155    1
# Name: target, Length: 360, dtype: int64

# %%
dtrain = xgb.DMatrix(X_train, label=y_train.replace(mapper))
dtest = xgb.DMatrix(X_test, label=y_test.replace(mapper))

# %%
# parámetros para el cross validation
param = {
    'max_depth': 3,  # the maximum depth of each tree
    'eta': 0.3,  # the training step for each iteration
    'objective': 'multi:softprob',  # error evaluation for multiclass training
    'num_class': 2}  # the number of classes that exist in this datset
num_round = 20  # the number of training iterations

# %%
# haz la cross validation con los siguientes parámetros
# nfold=3, num_boost_round=50, early_stopping_rounds=10,  as_pandas=True,seed=42

# %%
## grid para hacer el randomizedSearchCV xgboost hyperparámetros
## ojo! aquí como estimador hay que usar XGBClassifier
param_grid = {
    'max_depth': [3,5,7],  # the maximum depth of each tree
    'eta': [0.1,0.3],  # the training step for each iteration
    'objective': ['binary:logistic'],  # error evaluation for multiclass training
    }  # the number of classes that exist in this datset
num_round = 20  # the number of training iterations

# %% [markdown]
# ## metodos bayesianos

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

space= {
    'max_depth': hp.choice('max_depth', np.arange(1, 14, dtype=int)), #hp.quniform("max_depth", 3, 18, 1),
    'eta': 0.3,  # the training step for each iteration
    'objective': 'multi:softprob',  # error evaluation for multiclass training
    'num_class': 2}

def objective(space):
    clf=xgb.XGBClassifier(
                    **space)


    clf.fit(X_train, y_train,
            verbose=False)


    pred = clf.predict(X_test)
    best_preds = np.asarray([np.argmax(line) for line in pred])

    score = roc_auc_score(y_test, best_preds)
    #print ("SCORE:", accuracy)
    loss = 1 - score
    return {'loss': loss, 'status': STATUS_OK }
trials = Trials()

best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 100,
                        trials = trials)
#best_hyperparams = {key:int(val) if val.is_integer() else val for key, val in best_hyperparams.items()}
# Out:
# 100%|██████████| 100/100 [00:19<00:00,  5.14trial/s, best loss: 0.32210812443370584]

# %%
print("The best hyperparameters are : ","\n")
print(best_hyperparams)
# Out:
# The best hyperparameters are :
#
# {'max_depth': 5}

# %%
best_hyperparams.update({'eta': 0.3,  # the training step for each iteration
    'objective': 'multi:softprob',  # error evaluation for multiclass training
    'num_class': 2})

# %%
from xgboost.sklearn import XGBClassifier
bst = xgb.train(best_hyperparams, dtrain, num_round)
y_pred = bst.predict(dtest)
best_preds = np.asarray([np.argmax(line) for line in y_pred])
score = roc_auc_score(y_test, best_preds)
print(confusion_matrix(y_test, best_preds))
print(classification_report(y_test, best_preds))
print(score)
# Out:
# [[18 25]
#  [11 66]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.42      0.50        43
#            1       0.73      0.86      0.79        77
#
#     accuracy                           0.70       120
#    macro avg       0.67      0.64      0.64       120
# weighted avg       0.69      0.70      0.68       120
#
# 0.6378737541528239

# %% [markdown]
# ### Algoritmos genéticos

# %%
TPOTClassifier?

# %%
import tpot
from tpot import TPOTClassifier
import sklearn


scorer = sklearn.metrics.get_scorer('roc_auc_ovr')

est = tpot.TPOTClassifier(
    scorers=[scorer, tpot.objectives.complexity_scorer],
    scorers_weights=[1.0, -1.0],

    search_space="linear",
    generations=3, population_size=4,
    n_jobs=4,
    max_time_mins=60,
    max_eval_time_mins=10,
    early_stop=2,
    verbose=2,)
est.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/tpot/tpot_estimator/estimator.py:456: UserWarning: Both generations and max_time_mins are set. TPOT will terminate when the first condition is met.
#   warnings.warn("Both generations and max_time_mins are set. TPOT will terminate when the first condition is met.")
# INFO:distributed.http.proxy:To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:46117
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:35523'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:33223'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:40907'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:33283'
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:38595', name: 1, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:38595
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:59052
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:46829', name: 2, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:46829
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:59056
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:38799', name: 0, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:38799
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:59058
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:35675', name: 3, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:35675
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:57046
# INFO:distributed.scheduler:Receive client connection: Client-20fd039e-f601-11ef-81b5-0242ac1c000c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:59062
# /usr/local/lib/python3.11/dist-packages/tpot/tpot_estimator/estimator.py:535: UserWarning: Labels are not encoded as ints from 0 to N. For compatibility with some classifiers such as sklearn, TPOT has encoded y with the sklearn LabelEncoder. When using pipelines outside the main TPOT estimator class, you can encode the labels with est.label_encoder_
#   warnings.warn("Labels are not encoded as ints from 0 to N. For compatibility with some classifiers such as sklearn, TPOT has encoded y with the sklearn LabelEncoder. When using pipelines outside the main TPOT estimator class, you can encode the labels with est.label_encoder_")
# Generation: 100%|██████████| 3/3 [00:40<00:00, 13.56s/it]
# INFO:distributed.scheduler:Retire worker addresses (0, 1, 2, 3)
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:35523'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:33223'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:40907'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:33283'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:59058; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:59052; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:59056; closing.
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:38799', name: 0, status: closing, memory: 2, processing: 0> (stimulus_id='handle-worker-cleanup-1740767060.608116')
# ERROR:distributed.scheduler:Removing worker 'tcp://127.0.0.1:38799' caused the cluster to lose scattered data, which can't be recovered: {'DataFrame-9ac435803dc312019bde06c89e45f1f3', 'ndarray-445e39eaae57c296b8ae675c3784d181'} (stimulus_id='handle-worker-cleanup-1740767060.608116')
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:38595', name: 1, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1740767060.6295812')
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:46829', name: 2, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1740767060.6342943')
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:57046; closing.
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:35675', name: 3, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1740767060.6657734')
# INFO:distributed.scheduler:Lost all workers
# WARNING:distributed.nanny:Worker process still alive after 4.0 seconds, killing
# WARNING:distributed.nanny:Worker process still alive after 4.0 seconds, killing
# WARNING:distributed.nanny:Worker process still alive after 4.0 seconds, killing
# WARNING:distributed.nanny:Worker process still alive after 4.0 seconds, killing
# INFO:distributed.nanny:Worker process 17596 was killed by signal 9
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:33283' closed.
# INFO:distributed.nanny:Worker process 17585 was killed by signal 9
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:35523' closed.
# INFO:distributed.nanny:Worker process 17593 was killed by signal 9
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:40907' closed.
# INFO:distributed.nanny:Worker process 17589 was killed by signal 9
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:33223' closed.
# INFO:distributed.scheduler:Closing scheduler. Reason: unknown
# INFO:distributed.scheduler:Scheduler closing all comms
# TPOTClassifier(early_stop=2, n_jobs=4,
#                scorers=[make_scorer(roc_auc_score, response_method='predict_proba', multi_class=ovr),
#                         <function complexity_scorer at 0x7920c7174a40>],
#                scorers_weights=[1.0, -1.0],
#                search_space=<tpot.search_spaces.pipelines.sequential.SequentialPipeline object at 0x7920c6d1c190>)

# %%
best_pipeline = est.fitted_pipeline_
best_pipeline
# Out:
# Pipeline(steps=[('passthrough', Passthrough()),
#                 ('rfe',
#                  RFE(estimator=ExtraTreesClassifier(class_weight='balanced',
#                                                     max_features=0.8023713160815,
#                                                     min_samples_leaf=18,
#                                                     min_samples_split=7,
#                                                     n_jobs=1),
#                      step=0.0361346051267)),
#                 ('featureunion-1',
#                  FeatureUnion(transformer_list=[('featureunion',
#                                                  FeatureUnion(transformer_list=[('pca',
#                                                                                  PCA(n_components=0.5091240135282))])),
#                                                 ('passthrough',
#                                                  Passthrough())])),
#                 ('featureunion-2',
#                  FeatureUnion(transformer_list=[('skiptransformer',
#                                                  SkipTransformer()),
#                                                 ('passthrough',
#                                                  Passthrough())])),
#                 ('extratreesclassifier',
#                  ExtraTreesClassifier(class_weight='balanced',
#                                       criterion='entropy',
#                                       max_features=0.6833824465733,
#                                       min_samples_leaf=20, n_jobs=1))])

# %%
# Score on the test set

print(scorer(est, X_test, y_test))
# Out:
# 0.6946541830262761
