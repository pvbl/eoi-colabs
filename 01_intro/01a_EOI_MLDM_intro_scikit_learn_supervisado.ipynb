# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# 1. Generar datos sintéticos para clasificación
X, y = make_classification(n_samples=1000, n_features=20, n_informative=10, n_redundant=5, n_classes=2, random_state=42)

print(f"Forma de X: {X.shape}")
print(f"Forma de y: {y.shape}")
print(f"Número de clases: {len(set(y))}")
# Out:
# Forma de X: (1000, 20)
# Forma de y: (1000,)
# Número de clases: 2

# %%
# 2. Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Tamaño del conjunto de entrenamiento: {X_train.shape[0]} muestras")
print(f"Tamaño del conjunto de prueba: {X_test.shape[0]} muestras")
# Out:
# Tamaño del conjunto de entrenamiento: 700 muestras
# Tamaño del conjunto de prueba: 300 muestras

# %%
# 3. Inicializar el modelo
model = LogisticRegression(random_state=42, solver='liblinear')
# Out:
# Modelo de Regresión Logística entrenado.

# %%
# 4. entrenar el modelo
model.fit(X_train, y_train)

print("\nModelo de Regresión Logística entrenado.")

# %%
# 5. Realizar predicciones en el conjunto de prueba y evaluar el rendimiento
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"\nAccuracy: {accuracy:.4f}")
print("\nReporte de Clasificación:\n")
print(report)
# Out:
# Accuracy: 0.8367
#
# Reporte de Clasificación:
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       160
#            1       0.80      0.87      0.83       140
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.84       300
# weighted avg       0.84      0.84      0.84       300

# %% [markdown]
# # Ejercicio práctico

# %%
# carga las librerías de regresión lineal, métricas de mse y r2
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
# Partimos de los siguientes datos sintéticos
X_reg, y_reg = make_regression(n_samples=1000, n_features=20, n_informative=10, n_targets=1, noise=0.5, random_state=42)

print(f"Forma de X_reg: {X_reg.shape}")
print(f"Forma de y_reg: {y_reg.shape}")

# %%
# 2. Dividir los datos en conjuntos de entrenamiento y prueba, pon random_state = 42, test_size =0.3
X_train_reg, X_test_reg, y_train_reg, y_test_reg = #TODO
print(f"Tamaño del conjunto de entrenamiento (regresión): {X_train_reg.shape[0]} muestras")
print(f"Tamaño del conjunto de prueba (regresión): {X_test_reg.shape[0]} muestras")

# %%
# 3. Inicializar y entrenar un modelo de regresión lineal (sin parámetros)
model_reg = #TODO

# %%
# 4. entrena el modelo

#TODO
print("\nModelo de Regresión Lineal entrenado.")

# %%
# 5. Realizar predicciones en el conjunto de prueba y evaluar el modelo
y_pred_reg = #TODO

mse = #TODO
r2 = #TODO

print(f"\nError Cuadrático Medio (MSE): {mse:.4f}")
print(f"Coeficiente de Determinación (R^2): {r2:.4f}")

# %% [markdown]
# Haz el mismo ejercicio cambiando el random_state a diferentes valores, qué diferencias ves en las métricas del modelo?
